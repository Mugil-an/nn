# %%
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
import torch.nn as nn
sample = torch.tensor([10.,10.,10.])
linear = nn.Linear(3,3,bias = False)
print(linear(sample))
# Out:
# tensor([ 2.6364,  9.0050, -5.4873], grad_fn=<SqueezeBackward4>)
